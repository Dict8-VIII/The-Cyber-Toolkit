# %% [markdown]
# # Overpass
#
# - Look at the software, uses rot47. No obvious info in the source code
# - NMap Scan gives 22 and 80![Overpass_Nmap.png](attachment:b08aac4c-b6a0-4138-b9dd-b0173793ffd4.png)
# - Gobuster scan gives /admin![Overpass_Gobuster.png](attachment:00c9cabc-eb3e-4bfc-8df5-9416c5b4b000.png)
# - Looks to be a js issue, I'll have to come back to this one with some more experience
