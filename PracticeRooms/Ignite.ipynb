# %% [markdown]
# # Ignite
#
# ![Ignite_Nmap.png](attachment:27084188-c799-45ef-b391-1d25bc317f3c.png)
#
# ![Ignite_DefaultPage.png](attachment:594f0d38-de82-4bca-ab32-2c9f70551ee3.png)
#
# (i used (3)
# ![Ignite_ExploitDB.png](attachment:13d270de-72e6-4ab3-aecd-c0979a342558.png)
#
# ![Ignite_RunExploit.png](attachment:24c23e86-b380-444a-8eda-2a7b55677adc.png)
#
# - robots just has /fuel/
#
# bringing up /fuel gives as a login page. IF the home page is default, the password probably is too....
#
# ![Ignite_CreatePage.png](attachment:dcf3f493-d536-4425-a379-17abd44ad6ef.png)
#
# ![Ignite_AssestsUpload.png](attachment:b7b20e71-4e15-441d-a9da-f81e40c9143a.png)
#
# My PHP is uploaded... but not moved anywhere? maybe because I tried to upload it?
# ![Ignite_SomeoneHere.png](attachment:66e38377-086e-4671-bfa4-13b9caa7519d.png)
#
# ![Ignite_moveit.png](attachment:137f7f12-88b5-48f1-91af-5e0766af6831.png)
#
# ![Ignite_UserFlag.png](attachment:70173723-b7ba-4843-88e9-597ea924fcb1.png)
#
# stabalise & get scripts
#
# ![Ignite_GetEnum.png](attachment:d4fccd18-1d5c-4356-a154-e46a103ad230.png)
#
# Run linpeas
# ![Ignite_LinPeasPassword.png](attachment:c1ce0246-2542-4476-a23e-468edf243ebc.png)
# ![Ignite_LinpeasResults.png](attachment:a6ecc9bd-8a19-45c8-b9d0-3dec6dfa5c9d.png)
#
#
# capabilities, SUID no help
#
# ![Ignite_pwnkit.png](attachment:933a87e9-ee51-4bb5-93f1-3930ed64afde.png)
# https://www.qualys.com/2022/01/25/cve-2021-4034/pwnkit.txt
#
# ![Ignite_PwnkitReadme.png](attachment:3533e0d0-328b-4a85-a3a8-1893d6bd9657.png)
# ![Ignite_UbuntuVersion.png](attachment:f08408b2-d859-42c4-ab25-8f810cd7b6f5.png)
