# %% [markdown]
# # Startup
#
# 21,22,80 in nMAP
# ![Startup_Nmap.png](attachment:a5a2ed67-a81f-40df-b1a5-ec33decbfc91.png)
#
# Base page is quite empty, gobuster gives us /files
# ![Startup_GoBuster.png](attachment:2adaac84-e340-4bde-b06a-0b319217c540.png)
#
# - Important.jpg is a Among Us Meme
# - Notice.txt is a warning... that includes a name
#
# > Whoever is leaving these damn Among Us memes in this share, it IS NOT FUNNY. People downloading documents from our website will think we are a joke! Now I dont know who it is, but Maya is looking pretty sus.
#
# FTP allows anonymous
# ![Startup_FTPanonymous.png](attachment:5df8cc7b-1a1c-46f7-88b5-6f2f584c2101.png)
#
# Send a shell
# ![Startup_SendFTP.png](attachment:6b0e83f7-201c-418f-823e-a4e8da103f59.png)
#
# Do the things
# ![Startup_GetReverseShell.png](attachment:e0efb69b-2ec0-43a4-adec-d6d1a5407786.png)
#
# file is in the recipe.txt<br>
# there is a /incidents/suspicious.pcapng file... lets grab that
